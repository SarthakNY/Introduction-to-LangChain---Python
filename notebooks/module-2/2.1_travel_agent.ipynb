# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='148be29e-e1aa-49ad-aeb5-ad57e576c2d3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 511, 'prompt_tokens': 1229, 'total_tokens': 1740, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHvcqDWs5JNwypdhzHo2ZIZVvcJg4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cd8e5-b75b-7b30-ac63-7edcd8b9a31e-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'passengers': {'adults': 1}, 'cabinClass': 'M', 'currency': 'EUR', 'locale': 'en'}, 'id': 'call_PxpVFjyb6BYHefpJYBjBqthv', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 511, 'total_tokens': 1740, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n    "durationInSeconds": 98100,\n    "price": 554,\n    "deepLink": "https://on.kiwi.com/rOm8d7",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local": "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T03:25:00.000Z",\n      "local": "2026-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 72000,\n    "durationInSeconds": 72000,\n    "price": 727,\n    "deepLink": "https://on.kiwi.com/e0OZFn",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T23:55:00.000Z",\n          "local": "2026-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T13:25:00.000Z",\n      "local": "2026-04-01T22:25:00.000"\n    },\n    "totalDurationInSeconds": 106500,\n    "durationInSeconds": 106500,\n    "price": 538,\n    "deepLink": "https://on.kiwi.com/9qzqVs",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T02:10:00.000Z",\n          "local": "2026-04-01T10:10:00.000"\n        }\n      },\n      {\n        "at": "CTS",\n        "city": "Sapporo",\n        "cityCode": "SPK",\n        "arrival": {\n          "utc": "2026-04-01T06:00:00.000Z",\n          "local": "2026-04-01T15:00:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T11:50:00.000Z",\n          "local": "2026-04-01T20:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T13:40:00.000Z",\n      "local": "2026-04-01T22:40:00.000"\n    },\n    "totalDurationInSeconds": 107400,\n    "durationInSeconds": 107400,\n    "price": 548,\n    "deepLink": "https://on.kiwi.com/oqScR8",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T02:10:00.000Z",\n          "local": "2026-04-01T10:10:00.000"\n        }\n      },\n      {\n        "at": "CTS",\n        "city": "Sapporo",\n        "cityCode": "SPK",\n        "arrival": {\n      ...
#               AIMessage(content='Here are direct nonstop options from San Francisco (SFO) to Tokyo on March 31st. Prices are in EUR and include booking links.\n\n| Route (Direct) | Times (Local) | Cabin | Price (EUR) | Booking |\n|---|---|---|---|---|\n| SFO → NRT (Direct) | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | 1162 | https://on.kiwi.com/pQOWRT |\n| SFO → NRT (Direct) | 31/03 11:40 → 01/04 15:00 (11h 20m) | Economy | 1203 | https://on.kiwi.com/CiJ7Y1 |\n| SFO → NRT (Direct) | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | 1204 | https://on.kiwi.com/R6oItb |\n| SFO → HND (Direct) | 31/03 01:45 → 01/04 18:45 (11h 15m) | Economy | 1525 | https://on.kiwi.com/l8iENH |\n\nBest price: 1162 EUR for a direct SFO–NRT flight (Mar 31). Shortest direct option: 11h 5m on that same SFO–NRT route.\n\nRecommendation: If price matters most, book the 1162 EUR nonstop SFO→NRT flight. If you prefer Haneda for easier access to central Tokyo, the direct SFO→HND at 1525 EUR is a solid option.\n\nHave a great trip! Fun fact: Tokyo is home to the world’s most Michelin-starred city, with numerous standout sushi and ramen spots across its districts.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12570, 'prompt_tokens': 6222, 'total_tokens': 18792, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 12160, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DHvcz3BX5gA7JCIP7IdT3Eka2J8oI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd8e5-d9c4-7ae1-aa8b-96ecc83d6b8f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6222, 'output_tokens': 12570, 'total_tokens': 18792, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 12160}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct nonstop options from San Francisco (SFO) to Tokyo on March 31st. Prices are in EUR and include booking links.
#
# | Route (Direct) | Times (Local) | Cabin | Price (EUR) | Booking |
# |---|---|---|---|---|
# | SFO → NRT (Direct) | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | 1162 | https://on.kiwi.com/pQOWRT |
# | SFO → NRT (Direct) | 31/03 11:40 → 01/04 15:00 (11h 20m) | Economy | 1203 | https://on.kiwi.com/CiJ7Y1 |
# | SFO → NRT (Direct) | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | 1204 | https://on.kiwi.com/R6oItb |
# | SFO → HND (Direct) | 31/03 01:45 → 01/04 18:45 (11h 15m) | Economy | 1525 | https://on.kiwi.com/l8iENH |
#
# Best price: 1162 EUR for a direct SFO–NRT flight (Mar 31). Shortest direct option: 11h 5m on that same SFO–NRT route.
#
# Recommendation: If price matters most, book the 1162 EUR nonstop SFO→NRT flight. If you prefer Haneda for easier access to central Tokyo, the direct SFO→HND at 1525 EUR is a solid option.
#
# Have a great trip! Fun fact: Tokyo is home to the world’s most Michelin-starred city, with numerous standout sushi and ramen spots across its districts.
