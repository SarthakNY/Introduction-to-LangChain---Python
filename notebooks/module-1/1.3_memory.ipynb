# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='5bfdd571-5ba1-4b41-a851-896cf87e198e'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calm, fresh, and full of life.\n\nWhat would you like to do next? A few ideas:\n- Help you write a short self-introduction using your name and favorite color\n- Do a quick, fun trivia or discussion about the color green\n- Chat about your hobbies or a topic you’re interested in\n\nTell me what you’d prefer, or share something else you’d like to do.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 617, 'prompt_tokens': 18, 'total_tokens': 635, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxlJ99VL7Q7BXAOIUwqKn3aQOY2x', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-6d0a-7380-9396-00367ea56e73-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 617, 'total_tokens': 635, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='65aa60cc-c18d-4f96-ba55-b6ba4fa0f64d'),
#               AIMessage(content='I don’t know your favourite color yet—you haven’t told me. If you’d like, I can guess one for fun (blue is a common favorite), or we can figure it out with a couple quick questions:\n\n- Do you prefer calm, muted tones or bright, bold colors?\n- Do you wear mostly one color, or mix lots?\n- Do you feel drawn to nature-inspired greens and browns, or something else like red, purple, or yellow?\n\nTell me what you like, or I’ll go with blue as a guess.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 696, 'prompt_tokens': 11, 'total_tokens': 707, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxlPmFZj1ZkFVxOiGkrdzWMcUfin', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-83d6-7303-8da2-3d6b673e9c1c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 696, 'total_tokens': 707, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='70a5ee2a-9c0e-4a23-a367-93f623d9c2e7'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—calming and refreshing. What would you like to do today? I can chat, help with writing, brainstorm ideas, or create a green color palette (with hex codes) for a project. If you want, tell me the vibe you’re after (earthy, minty, emerald, etc.).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 725, 'prompt_tokens': 18, 'total_tokens': 743, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxlXUDTLc9HaqJ1toIYzOUrBdnsD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-a14a-7113-88fd-5cbe973367b8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 725, 'total_tokens': 743, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='70a5ee2a-9c0e-4a23-a367-93f623d9c2e7'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—calming and refreshing. What would you like to do today? I can chat, help with writing, brainstorm ideas, or create a green color palette (with hex codes) for a project. If you want, tell me the vibe you’re after (earthy, minty, emerald, etc.).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 725, 'prompt_tokens': 18, 'total_tokens': 743, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxlXUDTLc9HaqJ1toIYzOUrBdnsD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-a14a-7113-88fd-5cbe973367b8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 725, 'total_tokens': 743, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='5ca63a95-d8ad-40f3-83b8-813dea8eca9c'),
#               AIMessage(content='Your favourite colour is green.\n\nWould you like me to help with a green-themed palette? I can suggest shades (earthy olive, sage, mint, forest, emerald) and give hex codes or tailor it to a project.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 631, 'prompt_tokens': 109, 'total_tokens': 740, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxleKEsxNMLltMhHUI0YSRrtlVAr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-bd8e-7da3-acb1-e3bffeec3c3c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 631, 'total_tokens': 740, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}
