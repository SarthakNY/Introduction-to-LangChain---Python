# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or cities, so it has no capital. If you’re thinking of future colonies or fictional works, you might see invented names like “Lunapolis,” but none exists today.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Selene Prime.
#
# - Where it sits: along the rim of Shackleton Crater, near the Moon’s south pole. The city is perched to catch whatever sunlight reaches the rim while harvesting water ice from the crater interior.
# - Government: capital of the Lunar Confederation. The High Council meets in a hollow lava-tube turned government chamber, its memory-glass walls replaying past debates to guide present decisions.
# - Cityscape: a ring of pressurized glass-and-basalt domes connected by a network of lunar corridors called the Moonwalk. A towering Lumen Spire rises at the center, its parabolic reflectors funneling daylight down a vertical shaft to illuminate lower levels at all hours.
# - Landmarks:
#   - Lumen Spire: the pulse of the capital and a beacon for ships in orbit.
#   - Archive Dome: the vast data repository and cultural memory of the Moon.
#   - Ice Gate: the processing hub where subsurface ice is refined into water, air, and fuel.
#   - Hearth District: residential sectors with microgravity farms and communal HoloNets for education and entertainment.
# - Economy: water ice extraction, solar energy production, lunar industry (nanomaterials from regolith), and orbital trade hubs that ferry resources to Earth and beyond.
# - Culture: a cosmopolitan mix of Earth-born and lunar-born communities, centered on endurance, adaptation, and a festival of lumens when the long lunar day becomes a flood of light.
# - Vibe: a gleaming, practical metropolis built to endure vacuum, dust, and extremes, yet designed to feel like a city that finally has daylight on its own terms.
#
# Want a different vibe (e.g., a floating city inside a lava tube, or a poleward fortress city) or a quick scene set in Selene Prime?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Shackleton Crater rim, Moon's south polar region, along the sunlit terminator for solar power and access to frozen resources
# Vibe: Icebound metropolis
# Economy: Helium-3 and water-ice mining; high-tech manufacturing and nanofabrication; spaceport logistics and scientific research

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaria Prime', location='Shackleton Crater rim, lunar south pole region, at the sunlit edge overlooking permanently shadowed basins', vibe='crystal-lit, gravity-light metropolis where monastic calm meets orbital bustle; glassy domes, rotating gardens, and seamless transit arcs', economy='helium-3 and water-ice extraction, solar-energy grids, biotech and microgravity manufacturing, lunar tourism, and a thriving spaceport economy')

# %%
response["structured_response"].name
# Out:
# 'Lunaria Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaria Prime is a city located at Shackleton Crater rim, lunar south pole region, at the sunlit edge overlooking permanently shadowed basins
