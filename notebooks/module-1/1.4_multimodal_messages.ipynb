# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this fictional setting, the capital of The Moon is Selene Prime.
#
# Selene Prime sits on the sunlit rim of Shackleton Crater at the Moon’s southern pole. Its skyline is a tapestry of glass-domed districts and crystalline towers that glow softly as Earthrise washes over the horizon. The city is built to harvest every ray of light and every ounce of exposed ice, stitching life-support shields, solar arrays, and hydroponic farms into one living, breathing capital.
#
# Key features of Selene Prime:
# - Governance: The Lunar Conclave, a rotating council drawn from the Moon’s regional sectors, with a Prime Archivist as the ceremonial head. The Conclave oversees law, science policy, and interplanetary trade treaties.
# - Districts: The Glass Spires (seat of government and media), the Echo Quarter (cultural hub with lunar museums and performance domes), the Ingenium Crescent (research labs and manufacturing), and the Icefront Ward (habitats and water-ice processing).
# - Architecture and tech: Transparent-domed living streets, regolith-brick avenues, and kinetic-energy streets that harvest power from footsteps and hover traffic. Underground honeycombs store ice and fuel the city’s life-support systems.
# - Economy: Helium-3 and water-ice extraction form the backbone, complemented by data mining, lunar manufacturing, and a thriving arts-and-education sector that liaisons with Earth.
# - Transportation: Maglev tramways along crater rims, personal gravity shuttles, and tethered elevators connecting surface districts to subterranean facilities.
# - Culture: A blend of Earthly and lunar traditions, with the annual Silence Festival (a celebration of quiet and data streams) and the Earthrise Gallery, where art is projected directly into the dustless air.
#
# If you’d like, I can tailor Selene Prime to a specific era, political system, or tone (hopeful futurism, noir mystery, corporate-dominated metropolis, etc.).

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x0000020D21A907C0>, 'last_modified': datetime.datetime(2026, 3, 8, 0, 14, 21, 575000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# This capital is called Luminara, the luminous heart of the Caelum Dominion. It sits in a vast crater basin on the planet Caelum, overlooking jagged rock spires and a distant, pale-blue planet that dominates the sky. The city seems to rise from the canyon itself, a cathedral of glass, steel, and photon.
#
# What makes Luminara unique
# - Geography and atmosphere: The crater walls shelter a microclimate that the city tightly manages with energy domes and wind channels. Blue-lit pools gleam along the valley floor, fed by gravity-fed conduits that carry purified water and mineral slurry through the city’s rings and bridges.
# - Skyline and silhouette: The city’s centerpiece is the Beacon Spire, a ladder-like tower of crystalline alloy that channels solar and cosmic energy into the grid. Surrounding it are needle-thin towers, plateaus of living gardens, and elevated walkways that weave between districts like a lattice of light.
# - Architecture: Buildings are a blend of adaptive nanomaterials, glassy facades, and basalt-inspired stone textures. Facades shimmer with photonic skin that shifts color with the time of day or mood of the Council. Public spaces glow softly at night, guiding pedestrians with ambient aural cues and holographic mosaics.
#
# Districts and landmarks
# - The Prism Quarter: A dense, radiant area where market spirals, showroom towers, and citizen-hubs mingle. Street-level markets glow with illuminated textiles, holo-artisans, and nano-cuisine stalls.
# - The Old Quarter: Retains historic memory—ancient mineral tunnels widened into atria, preserved for their role in early energy experiments. It’s quieter, with museums, archives, and ceremonial plazas.
# - The Foundry Ring: Where heavy industry meets high tech. Catalytic furnaces and orbital-grade forges create energy conduits, propulsion components, and precision lenses.
# - The Echo Tunnels: A subterranean network that doubles as a cultural venue; sound travels like water here, producing haunting musical experiences and subterranean theater.
# - The Garden of Lumen: A rising belt of terraces and bioluminescent flora that absorbs excess energy and releases it as gentle light at dusk.
#
# Government and society
# - Governance: The Directorate of Lumen, a technocratic council drawn from eight guilds: Energy, Transit, Archive, Agriculture, Defense, Science, Culture, and Trade. Each guild governs its domain, but policy is coordinated by a rotating Luminal Council that answers to the citizen-assembly.
# - Economy: A credit system tied to energy production and efficiency; “Lumens” power the economy, but value is also tied to knowledge output, transit uptime, and cultural exports (art, music, holo-literature).
# - Culture: A culture of precision and beauty. Citizens wear lumen-weave fabrics that harvest light and glow in response to ambient energy fields. Public art merges with architecture—holographic murals shift with crowd movement, and street musicians tune to the city’s resonance.
#
# Technology and daily life
# - Transportation: A network of mag-lev corridors, skybridges, and drone taxis. Personal mobility often uses small, silent hover devices, while the upper levels run on rail and light-conduit transit for speed and efficiency.
# - Energy: The Beacon Spire collects and redistributes stellar and planetary energy. Transparent conduits create a visible web of power that hums with contained storms of photon and plasma.
# - Daily life: People live in modular residences that can scale up or down with family needs. Public spaces emphasize accessibility and safety, with weather-control corridors and climate-stable parks for all seasons.
#
# Notable features and stories
# - The Beacon: The symbolic and physical center of Luminara, a lighthouse for spacefaring neighbors and a symbol of the Dominion’s unity. It also serves as a massive energy reservoir and the constitutional meeting place for the Luminal Council.
# - The Azure Pits: Natural or engineered blue pools at the valley floor that glow under the city’s energy net. They’re a popular place for rituals, experiments, and quiet reflection.
# - The Archive of Stars: A vast subterranean vault and library of maps, star charts, and histories. Access is controlled by a guild of archivists who guard against misinformation and preserve memory.
# - The Festival of Light: An annual celebration when the city synchronizes its lumen-weave fabrics, holograms project shared histories, and public choirs sing in resonance with the Beacon. It’s a time when visitors are invited to participate in communal beam-weaving performances.
#
# History in brief
# - Founding and growth: Luminara arose after a crisis when Caelum’s energy grid collapsed. Engineers and scientists built a city that could harvest, store, and distribute energy while fostering culture and education.
# - Tensions: Rural mining enclaves outside the crater sometimes chafe under the direction of the Directorate, arguing for more local control of resources. There are ongoing debates about automation, labor, and the balance between efficiency and privacy.
# - Resilience: The city is known for its resilience—docker-like energy shields, adaptive infrastructure, and a culture of mutual aid when storms or outages threaten the energy grid.
#
# If you want a quick scene or tour idea
# - A tour through the Prism Quarter at dusk, watching the glass facades shift from cool blue to warm gold as energy floods the streets.
# - A clandestine meeting in the Echo Tunnels where archivists and engineers debate a new energy conduit that could change Caelum’s balance of power.
# - A ceremonial walk up the Beacon Spire during the Festival of Light, where every citizen’s lumen-weave aligns with the tower, creating a living aurora above the crater.
#
# If you’d like, I can tailor Luminara to a specific tone (political thriller, hopeful frontier, noir mystery, epic fantasy-tech), rename districts, or draft a short scene set in this capital.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.80it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# A feline friend with fur so fine,
# She dances softly, light divine.
# Her emerald eyes, a moonlit gleam,
# She tiptoes through each silent dream.
#
# With whiskers twitching in the air,
# She wanders freely, without care.
# Her velvet paws on midnight streets,
# Where shadows play and darkness meets.
#
# She purrs a song as soft as silk,
# A lullaby of warmth and milk.
# Her world is small, yet vast and grand,
# A regal queen of cushioned land.
#
# Oh gentle cat with playful heart,
# In every home you make your art.
# A quiet muse, a friend so true—
# The world is brighter, thanks to you.
