# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# Generally, my knowledge is not real-time. For the most recent deployments, my training data goes up to around late 2023, and I don’t have live web access unless browsing is enabled in your environment. I won’t know events or developments that occurred after that unless they’re provided to me or I’m explicitly allowed to browse.
#
# If you need up-to-date facts, tell me the topic and I can try to fetch current sources if browsing is available, or you can share a link or details and I can help interpret them.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9996699,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9979966,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.993255,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=Qvl6AMoZCoI',
#    'title': 'San Francisco Mayor-elect Daniel Lurie on transforming the city',
#    'content': "In a CNBC exclusive, San Francisco's new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,",
#    'score': 0.99242276,
#    'raw_content': None},
#   {'url': 'https://www.latimes.com/california/story/2025-04-14/the-vibe-shift-is-real-as-san-francisco-mayor-daniel-lurie-becomes-hometown-hype-man',
#    'title': "Daniel Lurie is San Francisco's nerdy new mayor — and hype man",
#    'content': "SAN FRANCISCO — When Daniel Lurie won election in November as San Francisco's new mayor, he knew there were daunting challenges ahead: the",
#    'score': 0.99155444,
#    'raw_content': None}],
#  'response_time': 0.74,
#  'request_id': '76f30533-4179-4a52-b464-a94cb072a268'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='561e60d8-cac5-4833-9525-3bf79fcb71d5'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 411, 'prompt_tokens': 133, 'total_tokens': 544, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxktn2CSG7RLoPJPcDahta2JQBSM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ccb2e-05c4-78c3-aea4-56d7178a7941-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'call_amHQlZSd9BEFi9F6lv9gFnpF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 411, 'total_tokens': 544, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.9995272, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=jKlTyBxpyT4", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on,", "score": 0.99632156, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured ...", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.9942697, "raw_content": null}, {"url": "https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election", "title": "Levi Strauss heir Daniel Lurie elected mayor of San ...", "content": "Levi Strauss heir Daniel Lurie elected mayor of San Francisco. Wealthy Democratic outsider unseats incumbent mayor London Breed in expensive race.", "score": 0.9937588, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco.", "score": 0.99155444, "raw_content": null}], "response_time": 0.75, "request_id": "e479c12e-9168-409e-a88d-713fe662131a"}', name='web_search', id='a54a01a0-fc90-49be-8e0f-60966aa1263b', tool_call_id='call_amHQlZSd9BEFi9F6lv9gFnpF'),
#  AIMessage(content='Daniel Lurie. He has been the mayor since 2024 (SF’s 46th mayor) and, as of 2026, is the incumbent. If you’d like, I can pull up current sources or details about his term.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 827, 'prompt_tokens': 642, 'total_tokens': 1469, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxkyIbZNZPiMnf1zzNYgEssbOhcQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb2e-193c-7d91-91f1-6f6d4017b94c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 642, 'output_tokens': 827, 'total_tokens': 1469, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
