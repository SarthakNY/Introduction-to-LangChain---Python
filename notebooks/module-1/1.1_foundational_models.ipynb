# %%
from dotenv import load_dotenv

load_dotenv('E:/Courses/Intro to Langchain/lca-lc-foundations-main/example.env')
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or political divisions, so it has no capital. (In fiction, authors may invent capitals for lunar nations, but none exist in reality.) If you’d like, I can outline how a future lunar governance model might work.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 512, 'prompt_tokens': 13, 'total_tokens': 525, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxeRvIyLsTLnWCJbaVrEOgMU9nb3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb27-e86e-72d3-a28d-21a3bbcda8e9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 512, 'total_tokens': 525, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or political divisions, so it has no capital. (In fiction, authors may invent capitals for lunar nations, but none exist in reality.) If you’d like, I can outline how a future lunar governance model might work.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DGxeRvIyLsTLnWCJbaVrEOgMU9nb3',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 512,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 448,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 525}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one—the Moon has no government or cities, so no capital. If a fictional universe or future settlement names a capital, that would be specified there.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1434, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
# -> 1434     _handle_anthropic_bad_request(e)
#    1435 return self._format_output(data, **kwargs)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1432, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1430 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1431 try:
# -> 1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
#    1434     _handle_anthropic_bad_request(e)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1286, in ChatAnthropic._create(self, payload)
#    1284 if "betas" in payload:
#    1285     return self._client.beta.messages.create(**payload)
# -> 1286 return self._client.messages.create(**payload)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\anthropic\_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File E:\Courses\Intro to Langchain\lca-lc-foundations-main\.venv\Lib\site-packages\anthropic\_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134             err.response.read()
#    1136         log.debug("Re-raising status error")
# -> 1137         raise self._make_status_error_from_response(err.response) from None
#    1139     break
#    1141 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CYpnHzD6ma7peMaJ9qx1S'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body with no permanent human settlements or governments.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6ca40159-317a-4e81-9331-1e9a55d37c4f'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. (In fiction some authors imagine capitals like “Lunapolis,” but that’s just storytelling.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 432, 'prompt_tokens': 13, 'total_tokens': 445, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DGxgNDCKFwmJUuKcEGGyQyDqxlka2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ccb29-b7c7-7081-b3a8-1e608508eb42-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 432, 'total_tokens': 445, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. (In fiction some authors imagine capitals like “Lunapolis,” but that’s just storytelling.)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='cecb0ff0-317b-4d2d-9bcb-28a1f7d4a237'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='7b745430-794a-49a2-a1b0-0886575ca270', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='4dbd7dfe-382b-4338-9ba3-a3cd5bef922f'),
#               AIMessage(content='Just to flag: Luna City isn’t real. It’s a fictional capital you might use for a story, game, or world-building. Here’s a fleshed-out concept you can riff on or adjust.\n\nOverview\n- Location: A populous hub on the Moon’s south polar region, built along a sunlit rim near Shackleton Crater. Water ice is mined nearby, while long, sunlit periods on the rim feed a big solar-energy complex. The city itself sits inside or beneath sheltered lava-tube caverns for radiation and micrometeoroid protection.\n- Purpose: The political and cultural center of a loose “Moon State” or Lunar Union. It houses the government, major research facilities, finance and trade councils, and a large, diverse resident population.\n\nGovernment and society\n- Governance: The Lunar Compact governs Moon-wide affairs, with Luna City hosting the Lunar Council—representatives from orbital colonies, surface habitats, and science outposts. A rotating Governor-General handles day-to-day administration; Earth serves as a closer partner with oversight on interplanetary law.\n- Population: Tens of thousands, including scientists, engineers, miners, educators, software and AI specialists, technicians, families, and artists. Children attend lunar academies that emphasize STEM and space heritage.\n- Daily life: Gravity is 1/6 g, so movement feels mischievous but manageable. Life centers on modular districts with shared amenities—greenhouses, libraries, clinics, schools, recreation hubs, and a vibrant market scene selling Earth goods and lunar crafts.\n\nInfrastructure and technology\n- Habitats: A mix of surface domes and protected lava-tube complexes. Pressure-stabilized apartments, common rooms, and community farms are connected by pressurized tunnels, elevators, and mag-lev transit.\n- Energy: Extensive solar farms on the sunlit rims power the city; heat and life support are provided by closed-loop systems. Small fission reactors or advanced reactors serve as backups for storms or long eclipse periods.\n- Water and food: Ice mined from nearby craters provides water; hydroponic and aeroponic farms supply fresh produce. Waste recycling and air revitalization are high-tech but transparent to residents.\n- Transport: Local transit uses magnetic rails and railcar-like shuttles. Surface rovers handle longer trips; elevators and airlocks connect different levels of the lava-tube habitats.\n- Defense and safety: Radiation shielding, micrometeoroid protection, dust management, and emergency shelter networks are built into every district. Regular drills and mental health support are standard.\n\nEconomy\n- Core industries: Scientific research and clean-room manufacturing, lunar ice and regolith processing, high-precision optics and components for space missions, biotech in closed ecosystems, and tourism (carefully regulated).\n- Trade: Lunar resources to Earth and vice versa—fuel, water, minerals, specialized machinery, and cultural exports like lunar art, music, and education programs.\n- Currency and finance: A lunar credit system linked to Earth-based currencies with special lunar credits for research, housing, and education subsidies.\n\nCulture and landmarks\n- Culture: A blend of Earth cultures with lunar sensibilities—community-first ethics, celebratory festivals tied to solar cycles, and a growing lunar-identity art scene. Storytelling often centers on exploration, resilience, and interplanetary cooperation.\n- Landmarks (sample ideas):\n  - The Dome of Dawn: A glassy observation and ceremony hall perched on a sunlit ledge, where elections and observances occur.\n  - The Ice Archives: A subterranean repository of data and ice cores, preserving lunar weather, geology, and human history.\n  - The Glass Gardens: A network of biomes where residents grow food and create art through light-science.\n  - The Moon Gate: A ceremonial transit hub linking lunar surface corridors to orbital transfer ports.\n  - The Spine: A central transit spine and ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional setting—the capital of the Moon in many sci‑fi worlds. There isn’t a real Luna City on the Moon today, but you can build a rich, coherent place around the idea. Below is a detailed concept you can use as a worldbuilding bible, plus an alternate-take flavor guide if you want a different vibe.
#
# Core concept
# - Luna City is the political heart, cultural beacon, and economic hub of a loose lunar federation or alliance of Moon settlements. It sits at the edge of a large lava-tube system or crater rim, where natural shielding from radiation and micrometeoroids combines with engineered megastructures to host a multi‑million‑person metropolis in space.
# - The city blends high-tech infrastructure with rugged, resource-driven practicality. It is a symbol of human resilience and ingenuity: a place where Earth’s influence is strong but lunar identity—self-reliance, engineering prowess, and community survival—shines just as bright.
#
# Setting and location
# - Location ideas (pick one or mix):
#   - Inside a massive lava tube near the Moon’s equatorial region, leveraging natural shielding, with sunlight redirected via surface heliostats to underground districts.
#   - On the crater rim of a permanently sunlit lava-pound region near the poles, using edge-shadow for thermal control and abundant water ice in nearby shadowed craters.
#   - In a crater within a mare basin, with elevated solar farms on the rim and a network of underground tunnels and domes beneath the floor.
# - Environment: eternal vigilance against radiation and temperature swings. Most living areas are within pressurized domes or lava-tube shelters. Some neighborhoods use rotating habitats to simulate Earth-like gravity; others rely on low-gravity acceleration in transit and microgravity workspaces.
#
# Governance and society
# - Political structure: a federated lunar authority or Lunar Council, with delegates from major districts (Government, Industry, Science, Agriculture, Culture, Security). The capital hosts the Council Chambers, the prime minister or governor’s palace, and the central judiciary.
# - Law and order: a Luna Security Authority (LSA) handles planetary secrecy, transit safety, resource rights, mining claims, and civil defense. Community councils in districts handle local matters and appeal to the central council.
# - Civic identity: a strong sense of lunar citizenship—not Earth-born or solar-citizen-only—emphasizing resourcefulness, scientific curiosity, and collective responsibility for the colony’s future.
# - Economy: a diversified lunar economy built on:
#   - Helium-3 and other resources mined and refined in nearby belts (handled through orbital stations and surface facilities).
#   - Solar energy farms and thermal storage powering city grids and export to Earth.
#   - Regolith-based manufacturing and 3D-printed construction materials.
#   - Greenhouses and hydroponics for food security, medicinal plants, and biotech research.
#   - Research and innovation districts drawing talent from Earth and Moon.
# - Culture and identity: cosmopolitan, with Earth diaspora communities and a growing “Moonborn” identity. Festivals celebrate Earth-Moon cooperation, moonlight photography, and the history of exploration.
#
# City design and districts
# - Core hub: a centrally located “Grand Dome” or “Capital Spire” complex housing government offices, the Supreme Court, central data centers, and the main transit hub. Circulating transit tubes and magnetically levitated pods connect districts.
# - Districts (illustrative names and roles):
#   - The Atrium District (government and civic life): council chambers, archives, museums, universities, and public plazas shaded by solar shields.
#   - The Core Manufacturing Belt (industry and engineering): lunar fabrication labs, assembly lines for spacecraft components, mining equipment fabrication, and airlock corridors for logistics.
#   - The Helios Belt (energy and commerce): solar arrays on the rim, energy storage facilities, trading houses, and a bustling lunar market with imports/exports from Earth.
#   - The Aether District (culture and science): observatories, research institutes, lunar symphony hall, art galleries, and planetarium.
#   - The Veridia Green (agriculture and ecology): controlled ecologies, greenhouses, algae bioreactors, water recycling facilities, and education farms.
#   - The Nerve and Nets (data, communications, cybersecurity): data centers, AI labs, space weather monitoring, and secure government networks.
#   - The Crater Market (habitation and transit hubs): living clusters, schools, clinics, and transit nodes; a lively, mixed-use zone with housing blocks, parks, and markets.
#   - The Quiet Shields (resilience and defense): emergency shelters, radiation shelters, and training grounds for civil defense and search-and-rescue.
# - Landmarks and features:
#   - The Dawn Gate: a ceremonial entrance to the city, symbolizing human arrival on the Moon.
#   - The Tesseract Data Spire: a twisting, high-density data center and public observation tower.
#   - The Silver Orchard: a symbolic public orchard in a dome, showcasing regenerative agriculture under glass.
#   - The Craterview Conservatory: a terraced greenhouse with lunar-arcade views into the crater.
#   - The Archive Spiral: a multi-level library and archives following a circular ramp through stacked centuries of lunar records.
#   - Transit arteries: a network of magnetic levitation pods, vacuum tubes, and rotating gravity corridors for comfortable Earth-like movement.
#
# Technology and daily life
# - Living spaces: modular, 3D-printed cells and apartments assembled from in-situ regolith composites; some neighborhoods use rotating habitats to provide Earth-like gravity for long-term health.
# - Power: solar farms on the rim and in shaded regions, with thermal storage and a compact nuclear/semiconductor micro-reactor option for heavy industry and backup.
# - Water and air: closed-loop life support; ice mined from shadowed craters turned into water; atmospheric regulators maintain stable pressure and air quality inside domes.
# - Food: hydroponic and aeroponic systems; algae bioreactors; microgreens; livestock is limited or simulated in controlled environments due to space constraints.
# - Transportation:
#   - Local: magnetic rail pods, surface shuttles, and vertical transit elevators in domes.
#   - Long-range: surface-to-orbit shuttles to lunar orbit hubs and occasional Earth-Moon shuttle lanes.
#   - Gravity management: some districts use spinning habitats or artificial gravity corridors to keep residents healthy.
# - Everyday tech: augmented reality interfaces for public services, autonomous logistics drones, AI-assisted governance, and robust cyber-resilience to protect critical systems.
#
# Challenges and tensions
# - Environmental: radiation shielding, dust management from regolith, and thermal control during day-night cycles.
# - Resource security: reliance on Earth for some materials, precarious supply lines, and tensions over mining rights near resource-rich zones.
# - Health and social: long-term exposure to low gravity, mental health in isolated environments, and digital/civic trust in automated governance.
# - Political: competing visions of Earth-Moon relations, lunar sovereignty vs. Earth oversight, and intercolony diplomacy with other lunar settlements.
# - Natural threats: solar storms, micrometeoroid impacts, and rare but dangerous seismic-like moonquakes within crustal areas.
#
# Notable people and institutions (example archetypes)
# - The Speaker of the Lunar Council: a diplomat-politician who balances Earth interests with lunar autonomy.
# - Chief Architect of Luna City: leads infrastructure and habitat design, specializing in resilient, adaptable domes.
# - Director of the Veridia Green: head of lunar agriculture and ecological systems.
# - Head of the LSA Cybernetics Division: oversees security, surveillance, and civil defense technologies.
# - Prominent universities and think tanks: pioneering lunar geology, astrophysics, biosciences, and closed-loop life support.
#
# Story prompts and hooks
# - A water-ice discovery in a nearby crater reconfigures lunar politics and reopens cold-war era debates about water rights.
# - A political scandal shatters the Lunar Council when a mismatch between Earth aid and lunar needs is revealed.
# - A bioengineer uncovers a method to optimize algae bio-reactors, triggering ethical debates about bio-enhancement and food sovereignty.
# - An unexplained power outage cripples a major district; investigators uncover a sophisticated cyber-attack with implications for the federation.
# - A delegation from Earth arrives for a historic treaty, but a lunar artist uncovers a hidden cultural agenda that threatens peace.
#
# Variants by vibe
# - Hard sci-fi Luna City: emphasize physics, life-support technology, realistic gravity and radiation models, and engineering challenges. Keep tech plausible and constraints tight.
# - Cyberpunk lunar city: grittier, more inequality, black markets in anti-grav tech, corporate-backed lunar districts, and noir political intrigue.
# - Utopian lunar metropolis: emphasize cooperative governance, abundant resources, green hydroponics, and peaceful coexistence with Earth and other colonies.
# - Detective/space opera Luna City: big government intrigue, high-stakes diplomacy, and high-speed transit chases through orbital tubes.
#
# If you’d like, I can tailor Luna City to a specific genre (hard sci‑fi, cyberpunk, or fantasy-adjacent science fiction), set a short lore timeline, or draft a sample map with districts and notable landmarks. Do you have a preferred tone, era, or origin story for Luna City?
